# %%
import pandas as pd
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
import numpy as np

import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, plot_confusion_matrix
from catboost import CatBoostClassifier
from sklearn.preprocessing import MinMaxScaler
import warnings
from pandas.plotting import parallel_coordinates

pd.options.display.float_format = '{:,.1f}'.format

from statsmodels.graphics.mosaicplot import mosaic

# %%
# define the dataset location
filename = 'adult-all.csv'
# load the csv file as a data frame
dataframe = pd.read_csv(filename, header=None, na_values='?')
dataframe.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'label']

dataframe = dataframe.dropna() # drop rows with missing


# dataframe['workclass'] = dataframe['workclass'].astype('category').cat.codes
# dataframe['education'] = dataframe['education'].astype('category').cat.codes
# dataframe['marital-status'] = dataframe['marital-status'].astype('category').cat.codes
# dataframe['occupation'] = dataframe['occupation'].astype('category').cat.codes
# dataframe['relationship'] = dataframe['relationship'].astype('category').cat.codes
# dataframe['race'] = dataframe['race'].astype('category').cat.codes
# dataframe['sex'] = dataframe['sex'].astype('category').cat.codes
# dataframe['native-country'] = dataframe['native-country'].astype('category').cat.codes
# dataframe['label'] = dataframe['label'].astype('category').cat.codes
# dataframe['label'] = dataframe['label'].astype('object')

dataframe.drop(columns='education-num') # education and education-num is the same thing
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 0       39         State-gov   77516     Bachelors          Never-married
# 1       50  Self-emp-not-inc   83311     Bachelors     Married-civ-spouse
# 2       38           Private  215646       HS-grad               Divorced
# 3       53           Private  234721          11th     Married-civ-spouse
# 4       28           Private  338409     Bachelors     Married-civ-spouse
# 5       37           Private  284582       Masters     Married-civ-spouse
# 6       49           Private  160187           9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 8       31           Private   45781       Masters          Never-married
# 9       42           Private  159449     Bachelors     Married-civ-spouse
# 10      37           Private  280464  Some-college     Married-civ-spouse
# 11      30         State-gov  141297     Bachelors     Married-civ-spouse
# 12      23           Private  122272     Bachelors          Never-married
# 13      32           Private  205019    Assoc-acdm          Never-married
# 15      34           Private  245487       7th-8th     Married-civ-spouse
# 16      25  Self-emp-not-inc  176756       HS-grad          Never-married
# 17      32           Private  186824       HS-grad          Never-married
# 18      38           Private   28887          11th     Married-civ-spouse
# 19      43  Self-emp-not-inc  292175       Masters               Divorced
# 20      40           Private  193524     Doctorate     Married-civ-spouse
# 21      54           Private  302146       HS-grad              Separated
# 22      35       Federal-gov   76845           9th     Married-civ-spouse
# 23      43           Private  117037          11th     Married-civ-spouse
# 24      59           Private  109015       HS-grad               Divorced
# 25      56         Local-gov  216851     Bachelors     Married-civ-spouse
# 26      19           Private  168294       HS-grad          Never-married
# 28      39           Private  367260       HS-grad               Divorced
# 29      49           Private  193366       HS-grad     Married-civ-spouse
# 30      23         Local-gov  190709    Assoc-acdm          Never-married
# 31      20           Private  266015  Some-college          Never-married
# ...    ...               ...     ...           ...                    ...
# 48809   25           Private  242136       HS-grad               Divorced
# 48810   31           Private  112115       HS-grad          Never-married
# 48811   49      Self-emp-inc   77132       HS-grad     Married-civ-spouse
# 48813   60           Private  117909     Assoc-voc     Married-civ-spouse
# 48814   39           Private  229647     Bachelors          Never-married
# 48815   38           Private  149347       Masters     Married-civ-spouse
# 48816   43         Local-gov   23157       Masters     Married-civ-spouse
# 48817   23           Private   93977       HS-grad          Never-married
# 48818   73      Self-emp-inc  159691  Some-college               Divorced
# 48819   35           Private  176967  Some-college     Married-civ-spouse
# 48820   66           Private  344436       HS-grad                Widowed
# 48821   27           Private  430340  Some-college          Never-married
# 48822   40           Private  202168   Prof-school     Married-civ-spouse
# 48823   51           Private   82720       HS-grad     Married-civ-spouse
# 48824   22           Private  269623  Some-college          Never-married
# 48825   64  Self-emp-not-inc  136405       HS-grad                Widowed
# 48827   55           Private  224655       HS-grad              Separated
# 48828   38           Private  247547     Assoc-voc          Never-married
# 48829   58           Private  292710    Assoc-acdm               Divorced
# 48830   32           Private  173449       HS-grad     Married-civ-spouse
# 48831   48           Private  285570       HS-grad     Married-civ-spouse
# 48832   61           Private   89686       HS-grad     Married-civ-spouse
# 48833   31           Private  440129       HS-grad     Married-civ-spouse
# 48834   25           Private  350977       HS-grad          Never-married
# 48835   48         Local-gov  349230       Masters               Divorced
# 48836   33           Private  245211     Bachelors          Never-married
# 48837   39           Private  215419     Bachelors               Divorced
# 48839   38           Private  374983     Bachelors     Married-civ-spouse
# 48840   44           Private   83891     Bachelors               Divorced
# 48841   35      Self-emp-inc  182148     Bachelors     Married-civ-spouse
#
#               occupation    relationship                race     sex  \
# 0           Adm-clerical   Not-in-family               White    Male
# 1        Exec-managerial         Husband               White    Male
# 2      Handlers-cleaners   Not-in-family               White    Male
# 3      Handlers-cleaners         Husband               Black    Male
# 4         Prof-specialty            Wife               Black  Female
# 5        Exec-managerial            Wife               White  Female
# 6          Other-service   Not-in-family               Black  Female
# 7        Exec-managerial         Husband               White    Male
# 8         Prof-specialty   Not-in-family               White  Female
# 9        Exec-managerial         Husband               White    Male
# 10       Exec-managerial         Husband               Black    Male
# 11        Prof-specialty         Husband  Asian-Pac-Islander    Male
# 12          Adm-clerical       Own-child               White  Female
# 13                 Sales   Not-in-family               Black    Male
# 15      Transport-moving         Husband  Amer-Indian-Eskimo    Male
# 16       Farming-fishing       Own-child               White    Male
# 17     Machine-op-inspct       Unmarried               White    Male
# 18                 Sales         Husband               White    Male
# 19       Exec-managerial       Unmarried               White  Female
# 20        Prof-specialty         Husband               White    Male
# 21         Other-service       Unmarried               Black  Female
# 22       Farming-fishing         Husband               Black    Male
# 23      Transport-moving         Husband               White    Male
# 24          Tech-support       Unmarried               White  Female
# 25          Tech-support         Husband               White    Male
# 26          Craft-repair       Own-child               White    Male
# 28       Exec-managerial   Not-in-family               White    Male
# 29          Craft-repair         Husband               White    Male
# 30       Protective-serv   Not-in-family               White    Male
# 31                 Sales       Own-child               Black    Male
# ...                  ...             ...                 ...     ...
# 48809  Machine-op-inspct   Not-in-family               Black    Male
# 48810  Machine-op-inspct   Not-in-family               White    Male
# 48811    Exec-managerial         Husband               White    Male
# 48813     Prof-specialty         Husband               White    Male
# 48814       Tech-support   Not-in-family               White  Female
# 48815     Prof-specialty         Husband               White    Male
# 48816    Exec-managerial         Husband               White    Male
# 48817  Machine-op-inspct       Own-child               White    Male
# 48818    Exec-managerial   Not-in-family               White  Female
# 48819    Protective-serv         Husband               White    Male
# 48820              Sales  Other-relative               White  Female
# 48821              Sales   Not-in-family               White  Female
# 48822     Prof-specialty         Husband               White    Male
# 48823       Craft-repair         Husband               White    Male
# 48824       Craft-repair       Own-child               White    Male
# 48825    Farming-fishing   Not-in-family               White    Male
# 48827    Priv-house-serv   Not-in-family               White  Female
# 48828       Adm-clerical       Unmarried               Black  Female
# 48829     Prof-specialty   Not-in-family               White    Male
# 48830  Handlers-cleaners         Husband               White    Male
# 48831       Adm-clerical         Husband               White    Male
# 48832              Sales         Husband               White    Male
# 48833       Craft-repair         Husband               White    Male
# 48834      Other-service       Own-child               White  Female
# 48835      Other-service   Not-in-family               White    Male
# 48836     Prof-specialty       Own-child               White    Male
# 48837     Prof-specialty   Not-in-family               White  Female
# 48839     Prof-specialty         Husband               White    Male
# 48840       Adm-clerical       Own-child  Asian-Pac-Islander    Male
# 48841    Exec-managerial         Husband               White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country  label
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# 5                 0             0              40  United-States  <=50K
# 6                 0             0              16        Jamaica  <=50K
# 7                 0             0              45  United-States   >50K
# 8             14084             0              50  United-States   >50K
# 9              5178             0              40  United-States   >50K
# 10                0             0              80  United-States   >50K
# 11                0             0              40          India   >50K
# 12                0             0              30  United-States  <=50K
# 13                0             0              50  United-States  <=50K
# 15                0             0              45         Mexico  <=50K
# 16                0             0              35  United-States  <=50K
# 17                0             0              40  United-States  <=50K
# 18                0             0              50  United-States  <=50K
# 19                0             0              45  United-States   >50K
# 20                0             0              60  United-States   >50K
# 21                0             0              20  United-States  <=50K
# 22                0             0              40  United-States  <=50K
# 23                0          2042              40  United-States  <=50K
# 24                0             0              40  United-States  <=50K
# 25                0             0              40  United-States   >50K
# 26                0             0              40  United-States  <=50K
# 28                0             0              80  United-States  <=50K
# 29                0             0              40  United-States  <=50K
# 30                0             0              52  United-States  <=50K
# 31                0             0              44  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48809             0             0              40  United-States  <=50K
# 48810             0             0              40  United-States  <=50K
# 48811             0             0              40         Canada   >50K
# 48813          7688             0              40  United-States   >50K
# 48814             0          1669              40  United-States  <=50K
# 48815             0             0              50  United-States   >50K
# 48816             0          1902              50  United-States   >50K
# 48817             0             0              40  United-States  <=50K
# 48818             0             0              40  United-States  <=50K
# 48819             0             0              40  United-States  <=50K
# 48820             0             0               8  United-States  <=50K
# 48821             0             0              45  United-States  <=50K
# 48822         15024             0              55  United-States   >50K
# 48823             0             0              40  United-States  <=50K
# 48824             0             0              40  United-States  <=50K
# 48825             0             0              32  United-States  <=50K
# 48827             0             0              32  United-States  <=50K
# 48828             0             0              40  United-States  <=50K
# 48829             0             0              36  United-States  <=50K
# 48830             0             0              40  United-States  <=50K
# 48831             0             0              40  United-States  <=50K
# 48832             0             0              48  United-States  <=50K
# 48833             0             0              40  United-States  <=50K
# 48834             0             0              40  United-States  <=50K
# 48835             0             0              40  United-States  <=50K
# 48836             0             0              40  United-States  <=50K
# 48837             0             0              36  United-States  <=50K
# 48839             0             0              50  United-States  <=50K
# 48840          5455             0              40  United-States  <=50K
# 48841             0             0              60  United-States   >50K
#
# [45222 rows x 14 columns]

# %%
plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(dataframe.corr(), dtype=np.bool))
heatmap = sns.heatmap(dataframe.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);
#dataframe.corr()
# plt.figure(figsize=(10,10))

# sns.heatmap(dataframe.corr(),annot=True,cmap='Blues')

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 
           'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'label']

# %%
temp = list(dataframe.dtypes)
intCols, objCols = [], []
for i in range(len(temp)):
    if(temp[i] == 'O'):
        objCols.append(columns[i])
    else:
        intCols.append(columns[i])
objCols = objCols[:-1]
print("Integer Type Columns:", intCols)
print("Object Type Columns:", objCols)
# Out:
# Integer Type Columns: ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# Object Type Columns: ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# %%
# catcols = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# intcols = ['age','fnlwgt', 'capital-loss', 'capital-gain', 'hours-per-week']

# plot = pd.plotting.scatter_matrix(dataframe[intcols], figsize=[25,25])

# colors = ['red', 'green']
# plot = pd.plotting.scatter_matrix(dataframe[intCols], figsize=[25, 25], marker='x', c=dataframe.label.apply(lambda x:colors[(x)]), s=80)

# %%
# colors = ['red', 'green']
# plot = pd.plotting.scatter_matrix(dataframe, figsize=[25, 25], marker='x', c=dataframe.label.apply(lambda x:colors[int(x)]), s=80)

# %%
# for col in dataframe.columns : 
#   sns.catplot(x='label', y = col, data=dataframe)

# %%
# fig, axes = plt.subplots(ncols=1, nrows=1, figsize=(15,20))
# fig.subplots_adjust(hspace=1)
# mosaic(dataframe, ['occupation', 'label'], ax=axes, axes_label=False)
# plt.show()

# %%
def emptyLabel(m):
    return ''

def createmulitvariatemosaicplots(col1, col2, col3,title):
    plt.rcParams["figure.figsize"]=(12, 10)
    mosaic(dataframe, [col1,col2,col3],
           gap=0.013, 
           label_rotation=45.0, 
           horizontal=False,
           title=title,
           labelizer=emptyLabel
          )
    plt.show()

# %%
createmulitvariatemosaicplots('sex','marital-status','label', 'Mosaic plot for Sex vs Marital Status vs Income')

# %%
dataframe
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# 13      32           Private  205019    Assoc-acdm             12
# 15      34           Private  245487       7th-8th              4
# 16      25  Self-emp-not-inc  176756       HS-grad              9
# 17      32           Private  186824       HS-grad              9
# 18      38           Private   28887          11th              7
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 21      54           Private  302146       HS-grad              9
# 22      35       Federal-gov   76845           9th              5
# 23      43           Private  117037          11th              7
# 24      59           Private  109015       HS-grad              9
# 25      56         Local-gov  216851     Bachelors             13
# 26      19           Private  168294       HS-grad              9
# 28      39           Private  367260       HS-grad              9
# 29      49           Private  193366       HS-grad              9
# 30      23         Local-gov  190709    Assoc-acdm             12
# 31      20           Private  266015  Some-college             10
# ...    ...               ...     ...           ...            ...
# 48809   25           Private  242136       HS-grad              9
# 48810   31           Private  112115       HS-grad              9
# 48811   49      Self-emp-inc   77132       HS-grad              9
# 48813   60           Private  117909     Assoc-voc             11
# 48814   39           Private  229647     Bachelors             13
# 48815   38           Private  149347       Masters             14
# 48816   43         Local-gov   23157       Masters             14
# 48817   23           Private   93977       HS-grad              9
# 48818   73      Self-emp-inc  159691  Some-college             10
# 48819   35           Private  176967  Some-college             10
# 48820   66           Private  344436       HS-grad              9
# 48821   27           Private  430340  Some-college             10
# 48822   40           Private  202168   Prof-school             15
# 48823   51           Private   82720       HS-grad              9
# 48824   22           Private  269623  Some-college             10
# 48825   64  Self-emp-not-inc  136405       HS-grad              9
# 48827   55           Private  224655       HS-grad              9
# 48828   38           Private  247547     Assoc-voc             11
# 48829   58           Private  292710    Assoc-acdm             12
# 48830   32           Private  173449       HS-grad              9
# 48831   48           Private  285570       HS-grad              9
# 48832   61           Private   89686       HS-grad              9
# 48833   31           Private  440129       HS-grad              9
# 48834   25           Private  350977       HS-grad              9
# 48835   48         Local-gov  349230       Masters             14
# 48836   33           Private  245211     Bachelors             13
# 48837   39           Private  215419     Bachelors             13
# 48839   38           Private  374983     Bachelors             13
# 48840   44           Private   83891     Bachelors             13
# 48841   35      Self-emp-inc  182148     Bachelors             13
#
#               marital-status         occupation    relationship  \
# 0              Never-married       Adm-clerical   Not-in-family
# 1         Married-civ-spouse    Exec-managerial         Husband
# 2                   Divorced  Handlers-cleaners   Not-in-family
# 3         Married-civ-spouse  Handlers-cleaners         Husband
# 4         Married-civ-spouse     Prof-specialty            Wife
# 5         Married-civ-spouse    Exec-managerial            Wife
# 6      Married-spouse-absent      Other-service   Not-in-family
# 7         Married-civ-spouse    Exec-managerial         Husband
# 8              Never-married     Prof-specialty   Not-in-family
# 9         Married-civ-spouse    Exec-managerial         Husband
# 10        Married-civ-spouse    Exec-managerial         Husband
# 11        Married-civ-spouse     Prof-specialty         Husband
# 12             Never-married       Adm-clerical       Own-child
# 13             Never-married              Sales   Not-in-family
# 15        Married-civ-spouse   Transport-moving         Husband
# 16             Never-married    Farming-fishing       Own-child
# 17             Never-married  Machine-op-inspct       Unmarried
# 18        Married-civ-spouse              Sales         Husband
# 19                  Divorced    Exec-managerial       Unmarried
# 20        Married-civ-spouse     Prof-specialty         Husband
# 21                 Separated      Other-service       Unmarried
# 22        Married-civ-spouse    Farming-fishing         Husband
# 23        Married-civ-spouse   Transport-moving         Husband
# 24                  Divorced       Tech-support       Unmarried
# 25        Married-civ-spouse       Tech-support         Husband
# 26             Never-married       Craft-repair       Own-child
# 28                  Divorced    Exec-managerial   Not-in-family
# 29        Married-civ-spouse       Craft-repair         Husband
# 30             Never-married    Protective-serv   Not-in-family
# 31             Never-married              Sales       Own-child
# ...                      ...                ...             ...
# 48809               Divorced  Machine-op-inspct   Not-in-family
# 48810          Never-married  Machine-op-inspct   Not-in-family
# 48811     Married-civ-spouse    Exec-managerial         Husband
# 48813     Married-civ-spouse     Prof-specialty         Husband
# 48814          Never-married       Tech-support   Not-in-family
# 48815     Married-civ-spouse     Prof-specialty         Husband
# 48816     Married-civ-spouse    Exec-managerial         Husband
# 48817          Never-married  Machine-op-inspct       Own-child
# 48818               Divorced    Exec-managerial   Not-in-family
# 48819     Married-civ-spouse    Protective-serv         Husband
# 48820                Widowed              Sales  Other-relative
# 48821          Never-married              Sales   Not-in-family
# 48822     Married-civ-spouse     Prof-specialty         Husband
# 48823     Married-civ-spouse       Craft-repair         Husband
# 48824          Never-married       Craft-repair       Own-child
# 48825                Widowed    Farming-fishing   Not-in-family
# 48827              Separated    Priv-house-serv   Not-in-family
# 48828          Never-married       Adm-clerical       Unmarried
# 48829               Divorced     Prof-specialty   Not-in-family
# 48830     Married-civ-spouse  Handlers-cleaners         Husband
# 48831     Married-civ-spouse       Adm-clerical         Husband
# 48832     Married-civ-spouse              Sales         Husband
# 48833     Married-civ-spouse       Craft-repair         Husband
# 48834          Never-married      Other-service       Own-child
# 48835               Divorced      Other-service   Not-in-family
# 48836          Never-married     Prof-specialty       Own-child
# 48837               Divorced     Prof-specialty   Not-in-family
# 48839     Married-civ-spouse     Prof-specialty         Husband
# 48840               Divorced       Adm-clerical       Own-child
# 48841     Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# 5                   White  Female             0             0              40
# 6                   Black  Female             0             0              16
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 12                  White  Female             0             0              30
# 13                  Black    Male             0             0              50
# 15     Amer-Indian-Eskimo    Male             0             0              45
# 16                  White    Male             0             0              35
# 17                  White    Male             0             0              40
# 18                  White    Male             0             0              50
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 21                  Black  Female             0             0              20
# 22                  Black    Male             0             0              40
# 23                  White    Male             0          2042              40
# 24                  White  Female             0             0              40
# 25                  White    Male             0             0              40
# 26                  White    Male             0             0              40
# 28                  White    Male             0             0              80
# 29                  White    Male             0             0              40
# 30                  White    Male             0             0              52
# 31                  Black    Male             0             0              44
# ...                   ...     ...           ...           ...             ...
# 48809               Black    Male             0             0              40
# 48810               White    Male             0             0              40
# 48811               White    Male             0             0              40
# 48813               White    Male          7688             0              40
# 48814               White  Female             0          1669              40
# 48815               White    Male             0             0              50
# 48816               White    Male             0          1902              50
# 48817               White    Male             0             0              40
# 48818               White  Female             0             0              40
# 48819               White    Male             0             0              40
# 48820               White  Female             0             0               8
# 48821               White  Female             0             0              45
# 48822               White    Male         15024             0              55
# 48823               White    Male             0             0              40
# 48824               White    Male             0             0              40
# 48825               White    Male             0             0              32
# 48827               White  Female             0             0              32
# 48828               Black  Female             0             0              40
# 48829               White    Male             0             0              36
# 48830               White    Male             0             0              40
# 48831               White    Male             0             0              40
# 48832               White    Male             0             0              48
# 48833               White    Male             0             0              40
# 48834               White  Female             0             0              40
# 48835               White    Male             0             0              40
# 48836               White    Male             0             0              40
# 48837               White  Female             0             0              36
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country  label
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# 5      United-States  <=50K
# 6            Jamaica  <=50K
# 7      United-States   >50K
# 8      United-States   >50K
# 9      United-States   >50K
# 10     United-States   >50K
# 11             India   >50K
# 12     United-States  <=50K
# 13     United-States  <=50K
# 15            Mexico  <=50K
# 16     United-States  <=50K
# 17     United-States  <=50K
# 18     United-States  <=50K
# 19     United-States   >50K
# 20     United-States   >50K
# 21     United-States  <=50K
# 22     United-States  <=50K
# 23     United-States  <=50K
# 24     United-States  <=50K
# 25     United-States   >50K
# 26     United-States  <=50K
# 28     United-States  <=50K
# 29     United-States  <=50K
# 30     United-States  <=50K
# 31     United-States  <=50K
# ...              ...    ...
# 48809  United-States  <=50K
# 48810  United-States  <=50K
# 48811         Canada   >50K
# 48813  United-States   >50K
# 48814  United-States  <=50K
# 48815  United-States   >50K
# 48816  United-States   >50K
# 48817  United-States  <=50K
# 48818  United-States  <=50K
# 48819  United-States  <=50K
# 48820  United-States  <=50K
# 48821  United-States  <=50K
# 48822  United-States   >50K
# 48823  United-States  <=50K
# 48824  United-States  <=50K
# 48825  United-States  <=50K
# 48827  United-States  <=50K
# 48828  United-States  <=50K
# 48829  United-States  <=50K
# 48830  United-States  <=50K
# 48831  United-States  <=50K
# 48832  United-States  <=50K
# 48833  United-States  <=50K
# 48834  United-States  <=50K
# 48835  United-States  <=50K
# 48836  United-States  <=50K
# 48837  United-States  <=50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K
#
# [45222 rows x 15 columns]

# %%
dataframe['class_label'] = dataframe['label'] == "<=50K"

# %%
def label(row):
    if(row['class_label']):
        return "Red"
    else:
        return "Blue"

dataframe['class_label'] = dataframe.apply(lambda row : label(row), axis = 1)
dataframe
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# 13      32           Private  205019    Assoc-acdm             12
# 15      34           Private  245487       7th-8th              4
# 16      25  Self-emp-not-inc  176756       HS-grad              9
# 17      32           Private  186824       HS-grad              9
# 18      38           Private   28887          11th              7
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 21      54           Private  302146       HS-grad              9
# 22      35       Federal-gov   76845           9th              5
# 23      43           Private  117037          11th              7
# 24      59           Private  109015       HS-grad              9
# 25      56         Local-gov  216851     Bachelors             13
# 26      19           Private  168294       HS-grad              9
# 28      39           Private  367260       HS-grad              9
# 29      49           Private  193366       HS-grad              9
# 30      23         Local-gov  190709    Assoc-acdm             12
# 31      20           Private  266015  Some-college             10
# ...    ...               ...     ...           ...            ...
# 48809   25           Private  242136       HS-grad              9
# 48810   31           Private  112115       HS-grad              9
# 48811   49      Self-emp-inc   77132       HS-grad              9
# 48813   60           Private  117909     Assoc-voc             11
# 48814   39           Private  229647     Bachelors             13
# 48815   38           Private  149347       Masters             14
# 48816   43         Local-gov   23157       Masters             14
# 48817   23           Private   93977       HS-grad              9
# 48818   73      Self-emp-inc  159691  Some-college             10
# 48819   35           Private  176967  Some-college             10
# 48820   66           Private  344436       HS-grad              9
# 48821   27           Private  430340  Some-college             10
# 48822   40           Private  202168   Prof-school             15
# 48823   51           Private   82720       HS-grad              9
# 48824   22           Private  269623  Some-college             10
# 48825   64  Self-emp-not-inc  136405       HS-grad              9
# 48827   55           Private  224655       HS-grad              9
# 48828   38           Private  247547     Assoc-voc             11
# 48829   58           Private  292710    Assoc-acdm             12
# 48830   32           Private  173449       HS-grad              9
# 48831   48           Private  285570       HS-grad              9
# 48832   61           Private   89686       HS-grad              9
# 48833   31           Private  440129       HS-grad              9
# 48834   25           Private  350977       HS-grad              9
# 48835   48         Local-gov  349230       Masters             14
# 48836   33           Private  245211     Bachelors             13
# 48837   39           Private  215419     Bachelors             13
# 48839   38           Private  374983     Bachelors             13
# 48840   44           Private   83891     Bachelors             13
# 48841   35      Self-emp-inc  182148     Bachelors             13
#
#               marital-status         occupation    relationship  \
# 0              Never-married       Adm-clerical   Not-in-family
# 1         Married-civ-spouse    Exec-managerial         Husband
# 2                   Divorced  Handlers-cleaners   Not-in-family
# 3         Married-civ-spouse  Handlers-cleaners         Husband
# 4         Married-civ-spouse     Prof-specialty            Wife
# 5         Married-civ-spouse    Exec-managerial            Wife
# 6      Married-spouse-absent      Other-service   Not-in-family
# 7         Married-civ-spouse    Exec-managerial         Husband
# 8              Never-married     Prof-specialty   Not-in-family
# 9         Married-civ-spouse    Exec-managerial         Husband
# 10        Married-civ-spouse    Exec-managerial         Husband
# 11        Married-civ-spouse     Prof-specialty         Husband
# 12             Never-married       Adm-clerical       Own-child
# 13             Never-married              Sales   Not-in-family
# 15        Married-civ-spouse   Transport-moving         Husband
# 16             Never-married    Farming-fishing       Own-child
# 17             Never-married  Machine-op-inspct       Unmarried
# 18        Married-civ-spouse              Sales         Husband
# 19                  Divorced    Exec-managerial       Unmarried
# 20        Married-civ-spouse     Prof-specialty         Husband
# 21                 Separated      Other-service       Unmarried
# 22        Married-civ-spouse    Farming-fishing         Husband
# 23        Married-civ-spouse   Transport-moving         Husband
# 24                  Divorced       Tech-support       Unmarried
# 25        Married-civ-spouse       Tech-support         Husband
# 26             Never-married       Craft-repair       Own-child
# 28                  Divorced    Exec-managerial   Not-in-family
# 29        Married-civ-spouse       Craft-repair         Husband
# 30             Never-married    Protective-serv   Not-in-family
# 31             Never-married              Sales       Own-child
# ...                      ...                ...             ...
# 48809               Divorced  Machine-op-inspct   Not-in-family
# 48810          Never-married  Machine-op-inspct   Not-in-family
# 48811     Married-civ-spouse    Exec-managerial         Husband
# 48813     Married-civ-spouse     Prof-specialty         Husband
# 48814          Never-married       Tech-support   Not-in-family
# 48815     Married-civ-spouse     Prof-specialty         Husband
# 48816     Married-civ-spouse    Exec-managerial         Husband
# 48817          Never-married  Machine-op-inspct       Own-child
# 48818               Divorced    Exec-managerial   Not-in-family
# 48819     Married-civ-spouse    Protective-serv         Husband
# 48820                Widowed              Sales  Other-relative
# 48821          Never-married              Sales   Not-in-family
# 48822     Married-civ-spouse     Prof-specialty         Husband
# 48823     Married-civ-spouse       Craft-repair         Husband
# 48824          Never-married       Craft-repair       Own-child
# 48825                Widowed    Farming-fishing   Not-in-family
# 48827              Separated    Priv-house-serv   Not-in-family
# 48828          Never-married       Adm-clerical       Unmarried
# 48829               Divorced     Prof-specialty   Not-in-family
# 48830     Married-civ-spouse  Handlers-cleaners         Husband
# 48831     Married-civ-spouse       Adm-clerical         Husband
# 48832     Married-civ-spouse              Sales         Husband
# 48833     Married-civ-spouse       Craft-repair         Husband
# 48834          Never-married      Other-service       Own-child
# 48835               Divorced      Other-service   Not-in-family
# 48836          Never-married     Prof-specialty       Own-child
# 48837               Divorced     Prof-specialty   Not-in-family
# 48839     Married-civ-spouse     Prof-specialty         Husband
# 48840               Divorced       Adm-clerical       Own-child
# 48841     Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# 5                   White  Female             0             0              40
# 6                   Black  Female             0             0              16
# 7                   White    Male             0             0              45
# 8                   White  Female         14084             0              50
# 9                   White    Male          5178             0              40
# 10                  Black    Male             0             0              80
# 11     Asian-Pac-Islander    Male             0             0              40
# 12                  White  Female             0             0              30
# 13                  Black    Male             0             0              50
# 15     Amer-Indian-Eskimo    Male             0             0              45
# 16                  White    Male             0             0              35
# 17                  White    Male             0             0              40
# 18                  White    Male             0             0              50
# 19                  White  Female             0             0              45
# 20                  White    Male             0             0              60
# 21                  Black  Female             0             0              20
# 22                  Black    Male             0             0              40
# 23                  White    Male             0          2042              40
# 24                  White  Female             0             0              40
# 25                  White    Male             0             0              40
# 26                  White    Male             0             0              40
# 28                  White    Male             0             0              80
# 29                  White    Male             0             0              40
# 30                  White    Male             0             0              52
# 31                  Black    Male             0             0              44
# ...                   ...     ...           ...           ...             ...
# 48809               Black    Male             0             0              40
# 48810               White    Male             0             0              40
# 48811               White    Male             0             0              40
# 48813               White    Male          7688             0              40
# 48814               White  Female             0          1669              40
# 48815               White    Male             0             0              50
# 48816               White    Male             0          1902              50
# 48817               White    Male             0             0              40
# 48818               White  Female             0             0              40
# 48819               White    Male             0             0              40
# 48820               White  Female             0             0               8
# 48821               White  Female             0             0              45
# 48822               White    Male         15024             0              55
# 48823               White    Male             0             0              40
# 48824               White    Male             0             0              40
# 48825               White    Male             0             0              32
# 48827               White  Female             0             0              32
# 48828               Black  Female             0             0              40
# 48829               White    Male             0             0              36
# 48830               White    Male             0             0              40
# 48831               White    Male             0             0              40
# 48832               White    Male             0             0              48
# 48833               White    Male             0             0              40
# 48834               White  Female             0             0              40
# 48835               White    Male             0             0              40
# 48836               White    Male             0             0              40
# 48837               White  Female             0             0              36
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native-country  label class_label
# 0      United-States  <=50K         Red
# 1      United-States  <=50K         Red
# 2      United-States  <=50K         Red
# 3      United-States  <=50K         Red
# 4               Cuba  <=50K         Red
# 5      United-States  <=50K         Red
# 6            Jamaica  <=50K         Red
# 7      United-States   >50K        Blue
# 8      United-States   >50K        Blue
# 9      United-States   >50K        Blue
# 10     United-States   >50K        Blue
# 11             India   >50K        Blue
# 12     United-States  <=50K         Red
# 13     United-States  <=50K         Red
# 15            Mexico  <=50K         Red
# 16     United-States  <=50K         Red
# 17     United-States  <=50K         Red
# 18     United-States  <=50K         Red
# 19     United-States   >50K        Blue
# 20     United-States   >50K        Blue
# 21     United-States  <=50K         Red
# 22     United-States  <=50K         Red
# 23     United-States  <=50K         Red
# 24     United-States  <=50K         Red
# 25     United-States   >50K        Blue
# 26     United-States  <=50K         Red
# 28     United-States  <=50K         Red
# 29     United-States  <=50K         Red
# 30     United-States  <=50K         Red
# 31     United-States  <=50K         Red
# ...              ...    ...         ...
# 48809  United-States  <=50K         Red
# 48810  United-States  <=50K         Red
# 48811         Canada   >50K        Blue
# 48813  United-States   >50K        Blue
# 48814  United-States  <=50K         Red
# 48815  United-States   >50K        Blue
# 48816  United-States   >50K        Blue
# 48817  United-States  <=50K         Red
# 48818  United-States  <=50K         Red
# 48819  United-States  <=50K         Red
# 48820  United-States  <=50K         Red
# 48821  United-States  <=50K         Red
# 48822  United-States   >50K        Blue
# 48823  United-States  <=50K         Red
# 48824  United-States  <=50K         Red
# 48825  United-States  <=50K         Red
# 48827  United-States  <=50K         Red
# 48828  United-States  <=50K         Red
# 48829  United-States  <=50K         Red
# 48830  United-States  <=50K         Red
# 48831  United-States  <=50K         Red
# 48832  United-States  <=50K         Red
# 48833  United-States  <=50K         Red
# 48834  United-States  <=50K         Red
# 48835  United-States  <=50K         Red
# 48836  United-States  <=50K         Red
# 48837  United-States  <=50K         Red
# 48839  United-States  <=50K         Red
# 48840  United-States  <=50K         Red
# 48841  United-States   >50K        Blue
#
# [45222 rows x 16 columns]

# %%
def plot_scatter(col1, col2,df,title):
    fig, axes = plt.subplots(1, 1, figsize = (10, 20))
    fig.subplots_adjust(hspace = 0.6, wspace = 0.4)
    
    colors = df['class_label']
    below50k = df[df['label'] == '<=50K']
    above50k = df[df['label'] == '>50K']
    
    c1 = below50k[col1]
    c2 = below50k[col2]
    
    axes.scatter(c1, c2, c = 'r', label = '<=50K')
    
    
    c1 = above50k[col1]
    c2 = above50k[col2]
    
    axes.scatter(c1, c2, c = 'b', label = '>50K')
    
    axes.legend()
    
    axes.set_title("red <=50K, blue >50K")
    axes.set_xlabel(col1)
    axes.set_ylabel(col2)
#         plt.rcParams["figure.figsize"]=(12, 10)
#         plt.title("Scatter plot for " + col1 + " vs " + col2)
#         plt.xlabel(col1)
#         plt.ylabel(col2)
#         plt.xticks(rotation=45)
#         plt.legend(['<=50K','>50K'])
#         plt.scatter(dataframe[col1], dataframe[col2],c=dataframe['label'].map({'<=50K': 'green', '>50K': 'red'}),
#                                alpha=0.5)


#         plt.show()

# %%
plot_scatter('education-num','capital-gain',dataframe,'Scatter plot')

# %%
# sns.scatterplot(x=dataframe["age"], y=dataframe["education-num"], hue=dataframe['label'])  

# plt.show()

# %%
sns.pairplot(dataframe, hue='label')  

plt.show()

# %%
def craeteparallelcoordinateplot_3c(dataframe,col1, col2, col3):
    plt.rcParams['figure.dpi'] = 70
    color_val = ['#556270', '#4ECDC4']
    df_copy = dataframe[[col1, col2, col3]].copy()
    #norm_df = pd.DataFrame(MinMaxScaler().fit_transform(df_copy), columns = [col1, col2, col3])
    norm_df=df_copy
    norm_df['label'] = dataframe['label']
    df_below50k = norm_df[norm_df['label'] == "<=50K"].sample(n = 50)
    df_above50k = norm_df[norm_df['label'] == ">50K"].sample(n = 50)
    norm_df_sampled = pd.concat([df_above50k, df_below50k])
    parallel_coordinates(norm_df_sampled, class_column='label', cols=[col1, col2, col3],color = color_val)

    plt.legend(loc="upper left", bbox_to_anchor=(1, 1), ncol=1)
    plt.title('Parallel Coordinate plot for '+col1 +' vs '+col2+' vs ' +col3,fontsize=16)
    plt.show()

# %%
craeteparallelcoordinateplot_3c(dataframe,'age','education-num','hours-per-week')
